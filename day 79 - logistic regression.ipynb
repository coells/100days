# %%
import numpy as np
from bokeh.plotting import figure, show, output_notebook

# %% [markdown]
# ## logistic regression

# %%
def logistic_regression(X, Y, W, lr=0.001, steps=1000):
    m = len(Y)
    sigmoid = lambda z: 1 / (1 + np.exp(-z))
    
    for _ in range(steps):
        # prediction
        hypothesis = sigmoid(X @ W)
        
        # fix overflow & underflow
        hypothesis = np.clip(hypothesis, 1e-5, 1 - 1e-5)
        
        # loss function, gradient, training
        loss = -1 / m * (Y @ np.log(hypothesis) + (1 - Y) @ np.log(1 - hypothesis))
        gradient = 1 / m * (X.T @ (hypothesis - Y))
        W -= lr * gradient
    
    # current loss & prediction
    return loss, sigmoid(X @ W)

# %% [markdown]
# ## data

# %%
n = 10000
# random values
x_, y_ = np.random.rand(2, n)
# polynomial coefficients
X = np.c_[np.ones(n), x_, y_, x_ ** 2, y_ ** 2]
# Y: target values
Y = (x_ - .5 <= (y_ - .5) ** 2) * 1
# weights
W = np.zeros(5)

# %% [markdown]
# ## train classification model

# %%
for _ in range(10):
    loss, H = logistic_regression(X, Y, W, lr=5., steps=1000)
    print(loss)
# Out:
# 0.0939072483492
# 0.0743423477901
# 0.0639064636228
# 0.057261603557
# 0.0525680284948
# 0.0490253057578
# 0.0462262933158
# 0.0439401890239
# 0.0420253995815
# 0.0403896777157

# %%
print('accuracy', np.mean(Y == H.round()))
print('weights', W)
# Out:
# accuracy 0.9912
# weights [ 24.48175955 -17.75464348 -38.46985456 -22.38533121  38.41771001]

# %% [markdown]
# ## plot

# %%
output_notebook()

palette = ['steelblue', 'red', 'lightgreen']
color = [palette[i] for i in (Y + H.round()).astype(int)]

plot = figure()
plot.circle(x_, y_, line_color='#c0c0c0', fill_color=color, alpha=.6, size=8)

show(plot)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e563c626-944e-44f4-a90e-450c3f52e6b6">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="97566e0d-b9a1-411d-a56e-43c19d0d4d3a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("97566e0d-b9a1-411d-a56e-43c19d0d4d3a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("97566e0d-b9a1-411d-a56e-43c19d0d4d3a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '97566e0d-b9a1-411d-a56e-43c19d0d4d3a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2d97d7b7-7ed4-4316-82b9-85ce25287a45":{"roots":{"references":[{"attributes":{"plot":{"id":"c71c6936-019a-4ff4-b635-1162410e9f3a","subtype":"Figure","type":"Plot"},"ticker":{"id":"558adce4-5b00-4097-ba86-c8defcc52497","type":"BasicTicker"}},"id":"d4a496dc-3dfb-42b5-b7dd-fa6ad00d2c1c","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"field":"fill_color"},"line_alpha":{"value":0.6},"line_color":{"value":"#c0c0c0"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"8553dba5-45f1-4066-a8f7-ff39ed076f67","type":"Circle"},{"attributes":{"plot":null,"text":""},"id":"2fa3e929-ca3f-4a68-be5a-8d2508d17660","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"1fdd8d72-4050-451f-a0e3-42cbd66af3da","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"dd98dfee-c92f-4df7-b24b-8ca70ca888ac","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"ac1cea91-daa5-4a25-87c5-15a9d6a08614","type":"BasicTickFormatter"},"plot":{"id":"c71c6936-019a-4ff4-b635-1162410e9f3a","subtype":"Figure","type":"Plot"},"ticker":{"id":"c31e3d94-abc1-4545-ae7b-b4bee661c186","type":"BasicTicker"}},"id":"641ab24c-08d6-4006-af74-9025f3f92482","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"c71c6936-019a-4ff4-b635-1162410e9f3a","subtype":"Figure","type":"Plot"},"ticker":{"id":"c31e3d94-abc1-4545-ae7b-b4bee661c186","type":"BasicTicker"}},"id":"daddaba9-6f9d-44ff-8381-af220d0942d9","type":"Grid"},{"attributes":{},"id":"c31e3d94-abc1-4545-ae7b-b4bee661c186","type":"BasicTicker"},{"attributes":{},"id":"ac1cea91-daa5-4a25-87c5-15a9d6a08614","type":"BasicTickFormatter"},{"attributes":{},"id":"721618a1-d938-4d58-a338-5562e566f640","type":"ToolEvents"},{"attributes":{"callback":null},"id":"9a59a182-babf-4794-b68f-fb19b305121d","type":"DataRange1d"},{"attributes":{"plot":{"id":"c71c6936-019a-4ff4-b635-1162410e9f3a","subtype":"Figure","type":"Plot"}},"id":"82e11688-7737-4a17-bb02-cc19babb2930","type":"PanTool"},{"attributes":{"plot":{"id":"c71c6936-019a-4ff4-b635-1162410e9f3a","subtype":"Figure","type":"Plot"}},"id":"47a1ddfd-10cc-44ea-8332-b5549adaae78","type":"HelpTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"82e11688-7737-4a17-bb02-cc19babb2930","type":"PanTool"},{"id":"6364ac41-57aa-4346-a4bc-fcbdcf6fd34d","type":"WheelZoomTool"},{"id":"1d02c6e5-a060-43de-8a1e-3cd7dca618ce","type":"BoxZoomTool"},{"id":"f0204a4f-ebd7-4200-972c-48b73e0d0f1e","type":"SaveTool"},{"id":"82857858-a880-4d68-a116-624378c5ddcf","type":"ResetTool"},{"id":"47a1ddfd-10cc-44ea-8332-b5549adaae78","type":"HelpTool"}]},"id":"28de2648-47d6-4399-b181-55f2f9930eb4","type":"Toolbar"},{"attributes":{"data_source":{"id":"97ee4de6-01f7-4eb1-bf8e-a41a38818b4b","type":"ColumnDataSource"},"glyph":{"id":"8553dba5-45f1-4066-a8f7-ff39ed076f67","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1fdd8d72-4050-451f-a0e3-42cbd66af3da","type":"Circle"},"selection_glyph":null},"id":"2697b6c3-818e-4824-bde3-6587eff87c38","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"aa00260d-c044-482a-a8bc-e028de2a55e8","type":"LinearAxis"}],"left":[{"id":"641ab24c-08d6-4006-af74-9025f3f92482","type":"LinearAxis"}],"renderers":[{"id":"aa00260d-c044-482a-a8bc-e028de2a55e8","type":"LinearAxis"},{"id":"d4a496dc-3dfb-42b5-b7dd-fa6ad00d2c1c","type":"Grid"},{"id":"641ab24c-08d6-4006-af74-9025f3f92482","type":"LinearAxis"},{"id":"daddaba9-6f9d-44ff-8381-af220d0942d9","type":"Grid"},{"id":"dd98dfee-c92f-4df ...
